# %%
import os

all_path = "F://backup//bin_data_3"
all_list = os.listdir(all_path)
for k in range(0, len(all_list)):
    folder_path = "F://backup//bin_data_3//" + str(all_list[k])
    folder_list = os.listdir(folder_path)
    for j in range(0,len(folder_list)):
        file_path = "F://backup//bin_data_3//" + str(all_list[k]) + "/" + folder_list[j]
        file = file_path + "/desktop.ini"
        print(file)
        if os.path.isfile(file):
            print("hi")
            os.remove(file)
# Out:
# F://backup//bin_data_3//0/2013-00-0089/desktop.ini
# hi
# F://backup//bin_data_3//0/2013-00-0161/desktop.ini
# hi
# F://backup//bin_data_3//0/2013-00-0179/desktop.ini
# hi
# F://backup//bin_data_3//0/2013-00-0198/desktop.ini
# hi
# F://backup//bin_data_3//0/2013-00-0204/desktop.ini
# hi
# F://backup//bin_data_3//0/2013-00-0270/desktop.ini
# hi
# F://backup//bin_data_3//0/2013-00-0283/desktop.ini
# hi
# F://backup//bin_data_3//0/2014-00-0019/desktop.ini
# hi
# F://backup//bin_data_3//0/2014-00-0050/desktop.ini
# hi
# F://backup//bin_data_3//0/2014-00-0075/desktop.ini
# hi
# F://backup//bin_data_3//0/2014-00-0201(보완)/desktop.ini
# hi
# F://backup//bin_data_3//0/2014-00-0244/desktop.ini
# hi
# F://backup//bin_data_3//0/2014-00-0246/desktop.ini
# hi
# F://backup//bin_data_3//0/2014-00-0272/desktop.ini
# hi
# F://backup//bin_data_3//0/2014-00-0279/desktop.ini
# hi
# F://backup//bin_data_3//0/2014-00-0315(2)/desktop.ini
# hi
# F://backup//bin_data_3//0/2014-00-0340/desktop.ini
# hi
# ...
