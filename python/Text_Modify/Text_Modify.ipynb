# %%
import numpy as np
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
f = open("/content/gdrive/My Drive/Cording/python/Text_Modify/train_list01.txt", 'r')
r = open("/content/gdrive/My Drive/Cording/python/Text_Modify/train_result.txt", 'w')

# %%
while True:  
  line = f.readline()
  if not line:
    break
  name_list = line.split('/')
  name = name_list[0]
  name_list2 = name_list[1].split(" ")
  lable = name_list2[1]
  avi_name = name_list2[0]
  new_lable = 'normal'
  if lable == '1\n':
    new_lable = 'abnormal'
  write_line = new_lable + '/' + avi_name + " " + str(int(lable[0])+1) + "\n"
  r.write(write_line)

r.close()
