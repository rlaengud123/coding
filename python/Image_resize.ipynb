# %%
import os
from PIL import Image

all_path = "f://cmc_data"
all_list = ['0_not_asb', '2_early_asb', '3_prog_asb']
for k in range(0, len(all_list)):
    folder_path = "f://cmc_data/" + str(all_list[k])
    folder_list = os.listdir(folder_path)
    folder_count = 0
    minimum = 1000
    booldir = "0"
    if (all_list[k] == "2_early_asb") or (all_list[k] == "3_prog_asb"):
        booldir = "1"
    for j in range(0,len(folder_list)):
        image_path = "f://cmc_data/" + str(all_list[k]) + "/" + folder_list[j] + "/s2"
        image_list = os.listdir(image_path)
        if len(image_list) != 0:
            if len(image_list) < minimum:
                minimum = len(image_list)
                path = image_path

        else:
            print(image_path)

    print("가장 적은 수의 이미지 : ", minimum, image_path )

    for j in range(0,len(folder_list)):
        image_path = "f://cmc_data/" + str(all_list[k]) + "/" + folder_list[j] + "/s2"
        image_list = os.listdir(image_path)
        folder_count = folder_count + 1
        count = 0
        if(len(image_list) > 30):
    #         if(len(image_list) > 40):
    #             cut_1 = int(len(image_list) * 0.1)
    #             cut_2 = int(len(image_list) * 0.9)
    #             image_list = image_list[cut_1:cut_2]
            for i in range(0,len(image_list)):

#                 a = int((len(image_list)/30)*i)

                if not os.path.isdir("f://cmc_resize/" + str(booldir) + "/" + str(folder_list[j])):
                    os.mkdir("f://cmc_resize/" + str(booldir) + "/" + str(folder_list[j]))


#                 if count == 30:
#                     break
                path = "f://cmc_data/" + str(all_list[k]) + "/" + str(folder_list[j]) + "/s2" + "/" + str(image_list[i]) #i가 아니라 a로 바꿔야함
                img = Image.open(path)
#                 size = (224,224)
#                 img = img.resize(size, Image.ANTIALIAS)
                sign_0 = "00"
                if count >= 10:
                    sign_0 = "0"
                if count >= 100:
                    sign_0 = ""
                new_path = "f://cmc_resize/" + str(booldir) + "/" + str(folder_list[j]) + "/" + sign_0 + str(count) +".bmp"
                img.save(new_path)
                count = count + 1
# Out:
# f://cmc_data/0_not_asb/2015-00-0350/s2
# f://cmc_data/0_not_asb/2016-00-0269/s2
# f://cmc_data/0_not_asb/28737586/s2
# f://cmc_data/0_not_asb/28922753/s2
# f://cmc_data/0_not_asb/28952995/s2
# f://cmc_data/0_not_asb/28983923/s2
# f://cmc_data/0_not_asb/28990584/s2
# f://cmc_data/0_not_asb/29004750/s2
# f://cmc_data/0_not_asb/29050771/s2
# f://cmc_data/0_not_asb/29059893/s2
# f://cmc_data/0_not_asb/29059964/s2
# f://cmc_data/0_not_asb/29082541/s2
# 가장 적은 수의 이미지 :  24 f://cmc_data/0_not_asb/9086982/s2
# 가장 적은 수의 이미지 :  20 f://cmc_data/2_early_asb/2017-00-0198/s2
# 가장 적은 수의 이미지 :  21 f://cmc_data/3_prog_asb/2017-01-0012/s2

# %%
import os
from PIL import Image

all_path = "f://data"
all_list = ['0', '1']
for k in range(0, len(all_list)):
    folder_path = "f://data/" + str(all_list[k])
    folder_list = os.listdir(folder_path)
    folder_count = 0
    aug_count = 1

    for j in range(0,len(folder_list)):
        image_path = "f://data/" + str(all_list[k]) + "/" + folder_list[j]
        image_list = os.listdir(image_path)
        folder_count = folder_count + 1
        count = 0
        if(len(image_list) > 30):
    #         if(len(image_list) > 40):
    #             cut_1 = int(len(image_list) * 0.1)
    #             cut_2 = int(len(image_list) * 0.9)
    #             image_list = image_list[cut_1:cut_2]
            for i in range(0,len(image_list)):

#                 a = int((len(image_list)/30)*i)

                if not os.path.isdir("f://data2/" + all_list[k] + "/" + str(folder_list[j])):
                    os.mkdir("f://data2/" + all_list[k] + "/" + str(folder_list[j]))


#                 if count == 30:
#                     break
                path = "f://data/" + str(all_list[k]) + "/" + str(folder_list[j]) + "/" + str(image_list[i]) #i가 아니라 a로 바꿔야함
                img = Image.open(path)
#                 size = (224,224)
#                 img = img.resize(size, Image.ANTIALIAS)
                sign_0 = "00"
                if count >= 10:
                    sign_0 = "0"
                if count >= 100:
                    sign_0 = ""
                new_path = "f://data2/" + all_list[k] + "/" + str(folder_list[j]) + "/" + sign_0 + str(count) +".bmp"
                img.save(new_path)
                if i % 7 == 0 or i % 5 == 0:
                    count = count + 1
                    sign_0 = "00"
                    if count >= 10:
                        sign_0 = "0"
                    if count >= 100:
                        sign_0 = ""
                    new_path = "f://data2/" + all_list[k] + "/" + str(folder_list[j]) + "/" + sign_0 + str(count) +".bmp"
                    img.save(new_path)
                count = count + 1

# %%
import os
from PIL import Image

all_path = "f://h_data"
all_list = ['1']
for k in range(0, len(all_list)):
    folder_path = "f://h_data/" + str(all_list[k])
    folder_list = os.listdir(folder_path)
    folder_count = 0
    aug_count = 1

    for j in range(0,len(folder_list)):
        image_path = "f://h_data/" + str(all_list[k]) + "/" + folder_list[j]
        image_list = os.listdir(image_path)
        folder_count = folder_count + 1
        count = 0
        if(len(image_list) > 30):
    #         if(len(image_list) > 40):
    #             cut_1 = int(len(image_list) * 0.1)
    #             cut_2 = int(len(image_list) * 0.9)
    #             image_list = image_list[cut_1:cut_2]
            for i in range(0,len(image_list)):

#                 a = int((len(image_list)/30)*i)

                if not os.path.isdir("f://h_data2/" + all_list[k] + "/" + str(folder_list[j])):
                    os.mkdir("f://h_data2/" + all_list[k] + "/" + str(folder_list[j]))


#                 if count == 30:
#                     break
                path = "f://h_data/" + str(all_list[k]) + "/" + str(folder_list[j]) + "/" + str(image_list[i]) #i가 아니라 a로 바꿔야함
                img = Image.open(path)
#                 size = (224,224)
#                 img = img.resize(size, Image.ANTIALIAS)
                sign_0 = "00"
                if count >= 10:
                    sign_0 = "0"
                if count >= 100:
                    sign_0 = ""
                new_path = "f://h_data2/" + all_list[k] + "/" + str(folder_list[j]) + "/" + sign_0 + str(count) +".bmp"
                img.save(new_path)
                # if i % 7 == 0 or i % 5 == 0:
                #     count = count + 1
                #     sign_0 = "00"
                #     if count >= 10:
                #         sign_0 = "0"
                #     if count >= 100:
                #         sign_0 = ""
                #     new_path = "f://h_data2/" + all_list[k] + "/" + str(folder_list[j]) + "/" + sign_0 + str(count) +".bmp"
                #     img.save(new_path)
                count = count + 1
