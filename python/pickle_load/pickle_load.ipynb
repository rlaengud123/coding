# %%
import tensorflow as tf
import pickle
import matplotlib.pyplot as plt
import numpy as np

# %%
with open("11", "rb") as f:
    data = pickle.load(f)

# %%
print(np.sum(data))
# Out:
# 21227130

# %%
print(data)
# Out:
# [72 72 72 ... 74 74 74]

# %%
data = tf.reshape(data, shape=[-1,224,224,3])

# %%
data.shape
data=tf.reshape(data, shape=[224,224,3])

# %%
plt.imshow(data)
